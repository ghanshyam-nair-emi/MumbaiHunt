# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\ghanshyam.nair\appdata\local\programs\python\python312\lib\site-packages (2.3.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import kagglehub
import pandas as pd
import numpy as np
import re
import random

# %% [markdown]
# Getting the Data

# %%
path = kagglehub.dataset_download("arvanshul/gurgaon-real-estate-99acres-com")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Ghanshyam.Nair\.cache\kagglehub\datasets\arvanshul\gurgaon-real-estate-99acres-com\versions\2

# %%
import os
print("Path:", path)
print("Files in path:", os.listdir(path))
# Out:
# Path: C:\Users\Ghanshyam.Nair\.cache\kagglehub\datasets\arvanshul\gurgaon-real-estate-99acres-com\versions\2
# Files in path: ['facets', 'gurgaon_10k.csv', 'hyderabad.csv', 'kolkata.csv', 'mumbai.csv']

# %%
df_mumbai_dataset.head()
# Out:
#        SPID    PROP_ID PREFERENCE  \
# 0  69306824  X69306824          S
# 1  70915032  R70915032          S
# 2  70916930  G70916930          P
# 3  70484400  H70484400          P
# 4  70484128  A70484128          P
#
#                                          DESCRIPTION          PROPERTY_TYPE  \
# 0  New brand 3bhk farmhouse with 68 guntha land f...             Farm House
# 1  Our residential plots & commercial plots are a...       Residential Land
# 2  Spacious bedroom with \nDouble size bed with d...  Residential Apartment
# 3  Pg for boys and girls available with price of:...  Residential Apartment
# 4  Pg for boys and girls in thane with below pric...  Residential Apartment
#
#                   CITY  TRANSACT_TYPE  OWNTYPE  BEDROOM_NUM  \
# 0  Mumbai Beyond Thane            1.0        1          3.0
# 1          Navi Mumbai            1.0        1          NaN
# 2                Thane            NaN        0          1.0
# 3                Thane            NaN        0          4.0
# 4                Thane            NaN        0          4.0
#
#    PRICE_PER_UNIT_AREA  ...  REGISTERED_DAYS  PRIMARY_TAGS  \
# 0               477941  ...      2 weeks ago  ['FEATURED']
# 1                  381  ...       6 days ago  ['FEATURED']
# 2                   51  ...       4 days ago            []
# 3                    6  ...      4 weeks ago            []
# 4                    6  ...      4 weeks ago            []
#
#                                       SECONDARY_TAGS  TOTAL_LANDMARK_COUNT  \
# 0                        ['READY TO MOVE', 'RESALE']                  14.0
# 1  ['CORNER PROPERTY', 'NORTH-EAST FACING', 'CIDC...                   NaN
# 2                      ['FURNISHED', 'PRIVATE ROOM']                  49.0
# 3                       ['FURNISHED', 'SHARED BY 2']                  39.0
# 4                       ['FURNISHED', 'SHARED BY 2']                  50.0
#
#                           FORMATTED_LANDMARK_DETAILS  \
# 0                          [{'text': '9 Hospitals'}]
# 1                                                NaN
# 2  [{'text': '2 Religious Places'}, {'text': '1 A...
# 3  [{'text': '1 Shopping'}, {'text': '3 Religious...
# 4  [{'text': '1 Shopping'}, {'text': '2 Religious...
#
#                  SOCIETY_NAME               BUILDING_NAME  \
# 0                         NaN                         NaN
# 1                   city prop                   city prop
# 2             Highway Darshan             Highway Darshan
# 3  Terraform Petunia, G Corp   Terraform Petunia, G Corp
# 4                         nul                         nul
#
#                                             location BALCONY_NUM FLOOR_NUM
# 0  {'CITY': '274', 'CITY_NAME': 'Mumbai Beyond Th...         1.0       NaN
# 1  {'CITY': '15', 'CITY_NAME': 'Navi Mumbai', 'BU...         NaN       NaN
# 2  {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...         1.0         1
# 3  {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...         2.0        11
# 4  {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...         2.0        25
#
# [5 rows x 55 columns]

# %%
df_mumbai_dataset.size
# Out:
# 523270

# %%
df_gurgoan_dataset = pd.read_csv(os.path.join(path, "gurgaon_10k.csv"))
# Out:
# C:\Users\Ghanshyam.Nair\AppData\Local\Temp\ipykernel_127184\3635639768.py:1: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_gurgoan_dataset = pd.read_csv(os.path.join(path, "gurgaon_10k.csv"))

# %%
df_gurgoan_dataset.head()
# Out:
#      PROP_ID                                          PHOTO_URL  \
# 0  O71585872  https://mediacdn.99acres.com/media1/22409/13/4...
# 1  T71585466  https://mediacdn.99acres.com/media1/22425/6/44...
# 2  D71549524  https://mediacdn.99acres.com/media1/22386/13/4...
# 3  I71493958  https://mediacdn.99acres.com/media1/22353/14/4...
# 4  H71479412  https://mediacdn.99acres.com/media1/22352/4/44...
#
#                                     MEDIUM_PHOTO_URL PREFERENCE  \
# 0  https://mediacdn.99acres.com/media1/22409/13/4...          S
# 1  https://mediacdn.99acres.com/media1/22425/6/44...          S
# 2  https://mediacdn.99acres.com/media1/22386/13/4...          R
# 3  https://mediacdn.99acres.com/media1/22353/14/4...          S
# 4  https://mediacdn.99acres.com/media1/22352/4/44...          R
#
#                                          DESCRIPTION          PROPERTY_TYPE  \
# 0    4 bhk flat for resale in alpha corp gurgaon one  Residential Apartment
# 1  Explore dlf ultima, an upscale ready-To-Move h...  Residential Apartment
# 2  A 3 bhk flat for rent in sector 66 gurgaon clo...  Residential Apartment
# 3  Looking for a 3 bhk property for purchase in g...  Residential Apartment
# 4  This 4 bhk flat in sector 104 gurgaon is avail...  Residential Apartment
#
#       CITY            LOCALITY  TRANSACT_TYPE  OWNTYPE  ...  LOCALITY_WO_CITY  \
# 0  Gurgaon   Sector 84 Gurgaon            1.0        1  ...         Sector 84
# 1  Gurgaon   Sector 81 Gurgaon            1.0        1  ...         Sector 81
# 2  Gurgaon   Sector 66 Gurgaon            NaN        0  ...         Sector 66
# 3  Gurgaon  Sector 112 Gurgaon            1.0        1  ...        Sector 112
# 4  Gurgaon  Sector 104 Gurgaon            NaN        0  ...        Sector 104
#
#                                              profile  \
# 0  {'CONTACT_NAME': 'gaurav khosla', 'CONTACT_COM...
# 1  {'CONTACT_NAME': 'Kamal', 'CONTACT_COMPANY_NAM...
# 2  {'CONTACT_NAME': 'Sandeep', 'CONTACT_COMPANY_N...
# 3  {'CONTACT_NAME': 'Kohli', 'CONTACT_COMPANY_NAM...
# 4  {'CONTACT_NAME': 'Kohli', 'CONTACT_COMPANY_NAM...
#
#                                                  xid  \
# 0  {'PROJECTID': 5096, 'PROJ_NAME': 'Alpha Corp G...
# 1  {'PROJECTID': 7182, 'PROJ_NAME': 'DLF The Ulti...
# 2  {'PROJECTID': 19, 'PROJ_NAME': 'Emaar MGF The ...
# 3  {'PROJECTID': 4342, 'PROJ_NAME': 'Experion Win...
# 4  {'PROJECTID': 25860, 'PROJ_NAME': 'ATS Triumph...
#
#                                             metadata  \
# 0  {'PROP_PHOTO_COUNT': '4', 'PROP_VIDEO_COUNT': ...
# 1  {'PROP_PHOTO_COUNT': '4', 'PROP_VIDEO_COUNT': ...
# 2  {'PROP_PHOTO_COUNT': '1', 'PROP_VIDEO_COUNT': ...
# 3  {'PROP_PHOTO_COUNT': '1', 'PROP_VIDEO_COUNT': ...
# 4  {'PROP_PHOTO_COUNT': '14', 'PROP_VIDEO_COUNT':...
#
#                                             location  BUILTUP_SQFT  \
# 0  {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDIN...           NaN
# 1  {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDIN...           NaN
# 2  {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDIN...       1920.00
# 3  {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDIN...       2225.56
# 4  {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDIN...           NaN
#
#    SUPER_SQFT COMMON_FURNISHING_ATTRIBUTES  QUALITY_SCORE  \
# 0         NaN                          NaN            NaN
# 1         NaN                          NaN            NaN
# 2         NaN                          NaN            NaN
# 3         NaN                          NaN            NaN
# 4         NaN                          NaN            NaN
#
#   FURNISHING_ATTRIBUTES
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 67 columns]

# %%
df_gurgoan_dataset.size
# Out:
# 717168

# %%
df_mumbai_dataset = pd.read_csv(os.path.join(path, "mumbai.csv"))
df_mumbai_dataset_narrowed = df_mumbai_dataset[["SPID", "PROP_ID", "PROPERTY_TYPE",'AREA','CITY','BEDROOM_NUM','PRICE_PER_UNIT_AREA','PROP_NAME','MIN_PRICE','MAX_PRICE','PRICE','PRICE_SQFT','MAP_DETAILS','location','PROP_HEADING','POSTING_DATE']]
df_mumbai_dataset_narrowed = df_mumbai_dataset_narrowed.dropna(subset=["BEDROOM_NUM"])

df_mumbai_dataset_narrowed = df_mumbai_dataset_narrowed[
    ~df_mumbai_dataset_narrowed["PRICE"].str.contains("Cr|L|Price on Request", na=False, case=False)
]

# %%
df_mumbai_dataset_narrowed.head()
# Out:
#        SPID    PROP_ID          PROPERTY_TYPE         AREA         CITY  \
# 2  70916930  G70916930  Residential Apartment   390 sq.ft.        Thane
# 3  70484400  H70484400  Residential Apartment  1250 sq.ft.        Thane
# 4  70484128  A70484128  Residential Apartment  1250 sq.ft.        Thane
# 5  70484644  C70484644  Residential Apartment  1125 sq.ft.        Thane
# 6  70816344  D70816344  Residential Apartment   850 sq.ft.  Navi Mumbai
#
#    BEDROOM_NUM  PRICE_PER_UNIT_AREA                          PROP_NAME  \
# 2          1.0                   51                    Highway Darshan
# 3          4.0                    6         Terraform Petunia, G Corp
# 4          4.0                    6                                nul
# 5          3.0                    7  Anurag Society , manthan society
# 6          2.0                    7                  Vintage Paying PG
#
#    MIN_PRICE  MAX_PRICE           PRICE  PRICE_SQFT  \
# 2      20000      20000  20,000/Bedroom          51
# 3       8000       8000       8,000/Bed           6
# 4       8000       8000       8,000/Bed           6
# 5       7500       7500       7,500/Bed           7
# 6       6000       6000       6,000/Bed           7
#
#                                          MAP_DETAILS  \
# 2  {'LATITUDE': '19.22071', 'LONGITUDE': '72.9867...
# 3  {'LATITUDE': '19.267984', 'LONGITUDE': '72.970...
# 4  {'LATITUDE': '19.25756', 'LONGITUDE': '72.98296'}
# 5  {'LATITUDE': '72.977264', 'LONGITUDE': '19.231...
# 6  {'LATITUDE': '19.029645', 'LONGITUDE': '73.020...
#
#                                             location  \
# 2  {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...
# 3  {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...
# 4  {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...
# 5  {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...
# 6  {'CITY': '15', 'CITY_NAME': 'Navi Mumbai', 'BU...
#
#                                      PROP_HEADING  POSTING_DATE
# 2                        1 BHK Flat in Thane West  1.692530e+12
# 3                    4 BHK Flat in Kasar vadavali  1.690540e+12
# 4                4 BHK Flat in Hiranandani Estate  1.690540e+12
# 5  3 BHK Flat in Louis Wadi close to wagle estate  1.690540e+12
# 6                   2 BHK Flat in Sector 21 Nerul  1.692090e+12

# %%
import ast

def extract_locality_name(x):
    if isinstance(x, dict):
        return x.get("LOCALITY_NAME")
    elif isinstance(x, str):
        try:
            # Convert string representation of dict to actual dict
            dict_obj = ast.literal_eval(x)
            return dict_obj.get("LOCALITY_NAME") if isinstance(dict_obj, dict) else None
        except:
            return None
    else:
        return None

df_new_scheme = pd.DataFrame()
df_new_scheme["area"] = df_mumbai_dataset_narrowed["CITY"]

df_new_scheme.head()
# Out:
#           area
# 2        Thane
# 3        Thane
# 4        Thane
# 5        Thane
# 6  Navi Mumbai

# %%
df_new_scheme["pricePerSquare"] = df_mumbai_dataset_narrowed["PRICE_PER_UNIT_AREA"]
df_new_scheme["rooms"] = df_mumbai_dataset_narrowed["BEDROOM_NUM"]
df_new_scheme["size"] = df_mumbai_dataset_narrowed["AREA"].str.split(" ").str[0].astype(float)

# %%
mask = df_mumbai_dataset_narrowed["PRICE"].str.contains("/Bed|/Bedroom", case=False, na=False)

# Extract the numeric value before "/Bed" or "/Bedroom"
# This regex captures numbers with commas: (\d{1,3}(?:,\d{3})*\.?\d*)
extracted_values = df_mumbai_dataset_narrowed["PRICE"].str.extract(r'(\d{1,3}(?:,\d{3})*\.?\d*)\s*/Bed(?:room)?', flags=re.IGNORECASE)[0]

print("Raw extracted values:", extracted_values[mask])

# Remove commas and convert to numeric
extracted_values = extracted_values.str.replace(',', '', regex=False)
extracted_values = pd.to_numeric(extracted_values, errors='coerce')

print("Cleaned extracted values:", extracted_values[mask])
print("BEDROOM_NUM values:", df_mumbai_dataset_narrowed.loc[mask, "BEDROOM_NUM"].values)

# Where the mask is True, multiply the extracted value by BEDROOM_NUM
df_mumbai_dataset_narrowed.loc[mask, "PRICE"] = (
    extracted_values[mask] * df_mumbai_dataset_narrowed.loc[mask, "BEDROOM_NUM"]
).astype(str)
# Out:
# Raw extracted values: 2       20,000
# 3        8,000
# 4        8,000
# 5        7,500
# 6        6,000
#          ...
# 4812    12,000
# 5224    32,000
# 6839     8,000
# 7702    10,000
# 7703     6,000
# Name: 0, Length: 1403, dtype: object
# Cleaned extracted values: 2       20000.0
# 3        8000.0
# 4        8000.0
# 5        7500.0
# 6        6000.0
#          ...
# 4812    12000.0
# 5224    32000.0
# 6839     8000.0
# 7702    10000.0
# 7703     6000.0
# Name: 0, Length: 1403, dtype: float64
# BEDROOM_NUM values: [1. 4. 4. ... 1. 1. 1.]

# %%
df_mumbai_dataset_narrowed.head(15)
# Out:
#         SPID    PROP_ID              PROPERTY_TYPE         AREA  \
# 2   70916930  G70916930      Residential Apartment   390 sq.ft.
# 3   70484400  H70484400      Residential Apartment  1250 sq.ft.
# 4   70484128  A70484128      Residential Apartment  1250 sq.ft.
# 5   70484644  C70484644      Residential Apartment  1125 sq.ft.
# 6   70816344  D70816344      Residential Apartment   850 sq.ft.
# 7   70486606  R70486606    Independent House/Villa  3000 sq.ft.
# 8   70485228  D70485228      Residential Apartment  1600 sq.ft.
# 9   70629508  K70629508      Residential Apartment  1000 sq.ft.
# 10  70038378  I70038378      Residential Apartment   600 sq.ft.
# 11  69809784  E69809784      Residential Apartment  1070 sq.ft.
# 12  70699774  G70699774      Residential Apartment   500 sq.ft.
# 13  70363976  C70363976           Studio Apartment   325 sq.ft.
# 14  70806490  N70806490      Residential Apartment   792 sq.ft.
# 15  70835204  L70835204    Independent House/Villa   850 sq.ft.
# 16  70247048  P70247048  Independent/Builder Floor  1000 sq.ft.
#
#                       CITY  BEDROOM_NUM  PRICE_PER_UNIT_AREA  \
# 2                    Thane          1.0                   51
# 3                    Thane          4.0                    6
# 4                    Thane          4.0                    6
# 5                    Thane          3.0                    7
# 6              Navi Mumbai          2.0                    7
# 7              Navi Mumbai          4.0                    2
# 8      Mumbai Beyond Thane          3.0                    3
# 9           Mumbai Harbour          2.0                   25
# 10            South Mumbai          3.0                   27
# 11  Central Mumbai suburbs          2.0                   23
# 12       Mumbai South West          1.0                   22
# 13       Mumbai South West          1.0                   49
# 14  Mumbai Andheri-Dahisar          2.0                  115
# 15             Navi Mumbai          4.0                    4
# 16  Mumbai Andheri-Dahisar          5.0                    8
#
#                             PROP_NAME  MIN_PRICE  MAX_PRICE    PRICE  \
# 2                     Highway Darshan      20000      20000  20000.0
# 3          Terraform Petunia, G Corp        8000       8000  32000.0
# 4                                 nul       8000       8000  32000.0
# 5   Anurag Society , manthan society        7500       7500  22500.0
# 6                   Vintage Paying PG       6000       6000  12000.0
# 7                    Shri Sai Darshan       6000       6000  24000.0
# 8                Bhiwandi Tata mantra       5000       5000  15000.0
# 9             blue diamond apartments      25000      25000  50000.0
# 10                 Churchgate Mansion      16500      16500  49500.0
# 11                      Lake Pleasant      25000      25000  50000.0
# 12  shivstan chs 20th road khar West       11000      11000  11000.0
# 13                           Alpa CHS      16000      16000  16000.0
# 14               Abhismit Aum Heights       8500       8500  17000.0
# 15                                NaN       4000       4000  16000.0
# 16                      prafull hall        8000       8000  40000.0
#
#     PRICE_SQFT                                        MAP_DETAILS  \
# 2           51  {'LATITUDE': '19.22071', 'LONGITUDE': '72.9867...
# 3            6  {'LATITUDE': '19.267984', 'LONGITUDE': '72.970...
# 4            6  {'LATITUDE': '19.25756', 'LONGITUDE': '72.98296'}
# 5            7  {'LATITUDE': '72.977264', 'LONGITUDE': '19.231...
# 6            7  {'LATITUDE': '19.029645', 'LONGITUDE': '73.020...
# 7            2  {'LATITUDE': '19.154494', 'LONGITUDE': '72.996...
# 8            3  {'LATITUDE': '19.268855', 'LONGITUDE': '73.045...
# 9           25  {'LATITUDE': '19.060577', 'LONGITUDE': '72.899...
# 10          27  {'LATITUDE': '18.93233', 'LONGITUDE': '72.8259...
# 11          23  {'LATITUDE': '19.117516', 'LONGITUDE': '72.908...
# 12          22  {'LATITUDE': '19.172613', 'LONGITUDE': '72.942...
# 13          49  {'LATITUDE': '19.100843544', 'LONGITUDE': '72....
# 14         115  {'LATITUDE': '19.160178', 'LONGITUDE': '72.835...
# 15           4  {'LATITUDE': '19.037049', 'LONGITUDE': '73.011...
# 16           8  {'LATITUDE': '19.1914596', 'LONGITUDE': '72.85...
#
#                                              location  \
# 2   {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...
# 3   {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...
# 4   {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...
# 5   {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDIN...
# 6   {'CITY': '15', 'CITY_NAME': 'Navi Mumbai', 'BU...
# 7   {'CITY': '15', 'CITY_NAME': 'Navi Mumbai', 'BU...
# 8   {'CITY': '274', 'CITY_NAME': 'Mumbai Beyond Th...
# 9   {'CITY': '13', 'CITY_NAME': 'Mumbai Harbour', ...
# 10  {'CITY': '16', 'CITY_NAME': 'South Mumbai', 'B...
# 11  {'CITY': '14', 'CITY_NAME': 'Central Mumbai su...
# 12  {'CITY': '17', 'CITY_NAME': 'Mumbai South West...
# 13  {'CITY': '17', 'CITY_NAME': 'Mumbai South West...
# 14  {'CITY': '218', 'CITY_NAME': 'Mumbai Andheri-D...
# 15  {'CITY': '15', 'CITY_NAME': 'Navi Mumbai', 'BU...
# 16  {'CITY': '218', 'CITY_NAME': 'Mumbai Andheri-D...
#
#                                          PROP_HEADING  POSTING_DATE
# 2                            1 BHK Flat in Thane West  1.692530e+12
# 3                        4 BHK Flat in Kasar vadavali  1.690540e+12
# 4                    4 BHK Flat in Hiranandani Estate  1.690540e+12
# 5      3 BHK Flat in Louis Wadi close to wagle estate  1.690540e+12
# 6                       2 BHK Flat in Sector 21 Nerul  1.692090e+12
# 7                  4 Bedroom House in Sector 4 Airoli  1.690550e+12
# 8                              3 BHK Flat in Bhiwandi  1.690540e+12
# 9                          2 BHK Flat in Chembur East  1.691220e+12
# 10                           3 BHK Flat in Churchgate  1.688420e+12
# 11                                2 BHK Flat in Powai  1.687350e+12
# 12                            1 BHK Flat in Dandpada,  1.691560e+12
# 13  Studio Apartments / 1 RK Flats in Vile Parle West  1.689940e+12
# 14                        2 BHK Flat in Shastri Nagar  1.692020e+12
# 15                4 Bedroom House in Sector 16A Nerul  1.692180e+12
# 16        5 BHK Independent Builder Floor in 8th road  1.689390e+12

# %%
df_new_scheme["monthlyFee"] = df_mumbai_dataset_narrowed["PRICE"]
df_new_scheme["endPrice"] = (
    pd.to_numeric(df_mumbai_dataset_narrowed["PRICE"], errors='coerce') - 
    ((random.randint(1, 10)/100) * pd.to_numeric(df_mumbai_dataset_narrowed["PRICE"], errors='coerce'))
)
df_new_scheme["askPrice"] = df_mumbai_dataset_narrowed["PRICE"]
df_new_scheme["perBedroomval"] = (
    pd.to_numeric(df_mumbai_dataset_narrowed["PRICE"], errors='coerce') / 
    pd.to_numeric(df_mumbai_dataset_narrowed["BEDROOM_NUM"], errors='coerce')
)
df_new_scheme["date"] = df_mumbai_dataset_narrowed["POSTING_DATE"]

# %%
df_new_scheme.head()
# Out:
#           area  pricePerSquare  rooms monthlyFee  endPrice askPrice  \
# 2        Thane              51    1.0    20000.0   19800.0  20000.0
# 3        Thane               6    4.0    32000.0   31680.0  32000.0
# 4        Thane               6    4.0    32000.0   31680.0  32000.0
# 5        Thane               7    3.0    22500.0   22275.0  22500.0
# 6  Navi Mumbai               7    2.0    12000.0   11880.0  12000.0
#
#    perBedroomval          date    size
# 2        20000.0  1.692530e+12   390.0
# 3         8000.0  1.690540e+12  1250.0
# 4         8000.0  1.690540e+12  1250.0
# 5         7500.0  1.690540e+12  1125.0
# 6         6000.0  1.692090e+12   850.0

# %%
# Save to file
df_new_scheme.to_json('output.json', orient='records', indent=2)
